# %%
 # Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import (
    Xception, preprocess_input, decode_predictions)

# %%
 # Load the Xception model
# https://keras.io/applications/#xception
model = Xception(
    include_top=True,
    weights='imagenet')

# %%
# Default Image Size for Xception
image_size = (299, 299)

# %%
# Check directory
os.getcwd()
# Out:
# 'C:\\Users\\Ryan\\OneDrive - ogg.com\\DU_class\\Projects\\rkustas.github.io\\keras'

# %%
# Load the image and resize to the input dimensions that Xception
# was trained with
image_path = os.path.join("../../../Caffeine-Project/Caffeine/", "Pics", "img_1.jpg")
img = image.load_img(image_path, target_size=image_size)
plt.imshow(img)

# %%
 # Preprocess image for model prediction
# This step handles scaling and normalization for Xception
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
 # Make predictions
predictions = model.predict(x)
print('Predicted:', decode_predictions(predictions, top=3)[0])
plt.imshow(img)
# Out:
# Predicted: [('n03916031', 'perfume', 0.23986427), ('n03690938', 'lotion', 0.17441796), ('n03314780', 'face_powder', 0.112557776)]

# %%
 # Refactor above steps into reusable function
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3)[0])

# %%
# Try with another image
image_path = os.path.join("../../../Caffeine-Project/Caffeine/", "Pics", "img_2.jpg")
predict(image_path)
# Out:
# Predicted: [('n03937543', 'pill_bottle', 0.2552131), ('n03825788', 'nipple', 0.16431026), ('n04357314', 'sunscreen', 0.12821892)]

# %%
# Try the VGG19 model
 # Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
 # Load the VGG19 model
# https://keras.io/applications/#VGG19
modelVGG = VGG19(include_top=True, weights='imagenet')

# %%
# Change default image size for VGG19
 # Define default image size for VGG19
image_size_VGG19 = (224, 224)

# %%
# Try with another image in a different model
image_pathVGG = os.path.join("../../../Caffeine-Project/Caffeine/", "Pics", "img_2.jpg")

# %%
 # Refactor above steps into reusable function
def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_pathVGG, target_size=image_size_VGG19)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = modelVGG.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3)[0])

# %%
predict(image_pathVGG)
# Out:
# Predicted: [('n03916031', 'perfume', 0.3707412), ('n03584254', 'iPod', 0.13467483), ('n04557648', 'water_bottle', 0.094387524)]

# %% [markdown]
# ## None of the above pretrained models worked well

# %%
# Dependencies
import pandas as pd
import matplotlib as mp
import numpy as np

# %%
# Load datasets
path1 = os.path.join("../../../Caffeine-Project/Caffeine/", "CSVs", "All_drink_info.csv")
path2 = os.path.join("../../../Caffeine-Project/Caffeine/", "CSVs", "Caffeine_intensity.csv")
drink_df = pd.read_csv(path1)
caff_intdf = pd.read_csv(path2)

# %%
drink_df.head()
# Out:
#                    drinks  caff_cont  fluid_oz  mg_per_oz  \
# 0     10 Hour Energy Shot        422      1.93      218.7
# 1   28 Black Energy Drink         80      8.46        9.5
# 2                3 Water          50     16.90        3.0
# 3         3D Energy Drink        200     16.00       12.5
# 4  4 Purpose Energy Drink         70      8.46        8.3
#
#                                                  url
# 0  https://www.caffeineinformer.com/caffeine-cont...
# 1  https://www.caffeineinformer.com/caffeine-cont...
# 2  https://www.caffeineinformer.com/caffeine-cont...
# 3  https://www.caffeineinformer.com/caffeine-cont...
# 4  https://www.caffeineinformer.com/caffeine-cont...

# %%
caff_intdf.head()
# Out:
#     caff_str                                           item_img  \
# 0  DANGEROUS  https://caffeineinformer.com/wp-content/caffei...
# 1   MODERATE  https://caffeineinformer.com/wp-content/caffei...
# 2   MODERATE  https://caffeineinformer.com/wp-content/caffei...
# 3  VERY HIGH  https://caffeineinformer.com/wp-content/caffei...
# 4   MODERATE  https://caffeineinformer.com/wp-content/caffei...
#
#               drink_name
# 0    10 Hour Energy Shot
# 1  28 Black Energy Drink
# 2                3 Water
# 3        3D Energy Drink
# 4              4-Purpose

# %%
# Join DF
drinkscaffdf = drink_df.join(caff_intdf)
drinkscaffdf
# Out:
#                                   drinks  caff_cont  fluid_oz  mg_per_oz  \
# 0                    10 Hour Energy Shot        422      1.93      218.7
# 1                  28 Black Energy Drink         80      8.46        9.5
# 2                               3 Water          50     16.90        3.0
# 3                        3D Energy Drink        200     16.00       12.5
# 4                 4 Purpose Energy Drink         70      8.46        8.3
# ..                                   ...        ...       ...        ...
# 769                 ZipFizz Energy Drink        100     16.00        6.2
# 770          Zola Coconut Water Espresso        125     17.50        7.1
# 771  Zola Organic Hydrating Energy Drink        120     12.00       10.0
# 772          Zola Sparkling Energy Water        100     12.00        8.3
# 773           Zombie Blood Energy Potion         80      3.40       23.5
#
#                                                    url   caff_str  \
# 0    https://www.caffeineinformer.com/caffeine-cont...  DANGEROUS
# 1    https://www.caffeineinformer.com/caffeine-cont...   MODERATE
# 2    https://www.caffeineinformer.com/caffeine-cont...   MODERATE
# 3    https://www.caffeineinformer.com/caffeine-cont...  VERY HIGH
# 4    https://www.caffeineinformer.com/caffeine-cont...   MODERATE
# ..                                                 ...        ...
# 769  https://www.caffeineinformer.com/caffeine-cont...       HIGH
# 770  https://www.caffeineinformer.com/caffeine-cont...       HIGH
# 771  https://www.caffeineinformer.com/caffeine-cont...       HIGH
# 772  https://www.caffeineinformer.com/caffeine-cont...       HIGH
# 773  https://www.caffeineinformer.com/caffeine-cont...   MODERATE
#
#                                               item_img  \
# 0    https://caffeineinformer.com/wp-content/caffei...
# 1    https://caffeineinformer.com/wp-content/caffei...
# 2    https://caffeineinformer.com/wp-content/caffei...
# 3    https://caffeineinformer.com/wp-content/caffei...
# 4    https://caffeineinformer.com/wp-content/caffei...
# ..                                                 ...
# 769  https://caffeineinformer.com/wp-content/caffei...
# 770  https://caffeineinformer.com/wp-content/caffei...
# 771  https://caffeineinformer.com/wp-content/caffei...
# 772  https://caffeineinformer.com/wp-content/caffei...
# 773  https://caffeineinformer.com/wp-content/caffei...
#
#                               drink_name
# 0                    10 Hour Energy Shot
# 1                  28 Black Energy Drink
# 2                                3 Water
# 3                        3D Energy Drink
# 4                              4-Purpose
# ..                                   ...
# 769                 ZipFizz Energy Drink
# 770          Zola Coconut Water Espresso
# 771  Zola Organic Hydrating Energy Drink
# 772          Zola Sparkling Energy Water
# 773           Zombie Blood Energy Potion
#
# [774 rows x 8 columns]

# %%
# Drop unneeded columns
drinkscaffdf.drop(columns=['item_img'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-4ad9b0bdabef> in <module>
#       1 # Drop unneeded columns
# ----> 2 drinkscaffdf.drop(columns=['item_img'])
#
# ~\anaconda3\envs\Caffeine\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\envs\Caffeine\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\envs\Caffeine\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\envs\Caffeine\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['item_img'] not found in axis"
